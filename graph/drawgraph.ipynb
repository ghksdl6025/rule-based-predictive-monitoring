# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
plt.rcParams.update({'font.size': 10})

# %%
fig, ax = plt.subplots(6, 3, figsize=(18,30))
axdict = {'ax1':ax[0,0],'ax2':ax[0,1],'ax3':ax[0,2],
          'ax4':ax[1,0],'ax5':ax[1,1],'ax6':ax[1,2],
          'ax7':ax[2,0],'ax8':ax[2,1],'ax9':ax[2,2],
          'ax10':ax[3,0],'ax11':ax[3,1],'ax12':ax[3,2],
          'ax13':ax[4,0],'ax14':ax[4,1],'ax15':ax[4,2],
          'ax16':ax[5,0],'ax17':ax[5,1],'ax18':ax[5,2]}
marker ={'thirdmethod':'o','fourthmethod':'^','fifthmethod':'*','randomforest':'s','xgboost':'x'}
linestyle = {'thirdmethod': (0, (1, 10)),'fourthmethod':'dotted','fifthmethod':'dashed'}


# BPIC2015_1 label 0

label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+1)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')

# BPIC2015_1 label 1

label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+4)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')

# BPIC2015_2 label 0

label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+7)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')

# BPIC2015_2 label 1

label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+10)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')


# BPIC2015_3 label 0

label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+13)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')

legenddict={}
   
# BPIC2015_3 label 1
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+16)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        legenddict[plabel] = scoregraph

        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        legenddict[plabel] = scoregraph

        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')



fig.legend(legenddict.values(),     # The line objects
           labels=legenddict.keys(),   # The labels for each line
           loc="center right",   # Position of legend
               # Small spacing around legend box
           fontsize=20
           )
# plt.tight_layout()
plt.text(-16.5,5.85,'Precision',fontsize=20)
plt.text(-5.5,5.85,'Recall',fontsize=20)
plt.text(5,5.85,'F1-score',fontsize=20)

plt.text(-28.5,5.375,'BPIC 2015_1 Label 0',fontsize=20)
plt.text(-28.5,4.425,'BPIC 2015_1 Label 1',fontsize=20)
plt.text(-28.5,3.47,'BPIC 2015_2 Label 0',fontsize=20)
plt.text(-28.5,2.5,'BPIC 2015_2 Label 1',fontsize=20)
plt.text(-28.5,1.5,'BPIC 2015_3 Label 0',fontsize=20)
plt.text(-28.5,0.55,'BPIC 2015_3 Label 1',fontsize=20)

plt.subplots_adjust(left=0.2,right=0.87)
plt.subplots_adjust(right=0.85)
plt.savefig('./arm_ml1.pdf',bbox_inches='tight')
# Out:
# /home/iel03/.local/lib/python3.6/site-packages/ipykernel_launcher.py:270: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.

# %%
fig, ax = plt.subplots(4, 3, figsize=(18,20))
axdict = {'ax1':ax[0,0],'ax2':ax[0,1],'ax3':ax[0,2],
          'ax4':ax[1,0],'ax5':ax[1,1],'ax6':ax[1,2],
          'ax7':ax[2,0],'ax8':ax[2,1],'ax9':ax[2,2],
          'ax10':ax[3,0],'ax11':ax[3,1],'ax12':ax[3,2]}
          
# BPIC2011 label 0
marker ={'thirdmethod':'o','fourthmethod':'^','fifthmethod':'*','randomforest':'s','xgboost':'x'}
linestyle = {'thirdmethod': (0, (1, 10)),'fourthmethod':'dotted','fifthmethod':'dashed'}

label = 'Label 0'

for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+1)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')

# BPIC2011 label 1
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+4)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')

# Sepsis cases label 0

label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+7)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../sepsis/rule1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../sepsis/rule1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')

# Sepsis cases label 1
legenddict={}
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+10)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../sepsis/rule1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        
        legenddict[plabel] = scoregraph
        
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../sepsis/rule1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        
        legenddict[plabel] = scoregraph
        
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
    
fig.legend(legenddict.values(),     # The line objects
           labels=legenddict.keys(),   # The labels for each line
           loc="center right",   # Position of legend
               # Small spacing around legend box
           fontsize=20
           )
# plt.tight_layout()
plt.text(-16.5,4.65,'Precision',fontsize=20)
plt.text(-5.5,4.65,'Recall',fontsize=20)
plt.text(5,4.65,'F1-score',fontsize=20)

plt.text(-27.9,4.05,'BPIC 2011 Label 0',fontsize=20)
plt.text(-27.9,2.85,'BPIC 2011 Label 1',fontsize=20)
plt.text(-27.9,1.65,'Sepsis cases Label 0',fontsize=20)
plt.text(-27.9,0.45,'Sepsis cases Label 1',fontsize=20)

plt.subplots_adjust(left=0.2,right=0.87)
# plt.tight_layout()
plt.savefig('./arm_ml2
Python 3  Trusted 
File
Edit
View
Insert
Cell
Kernel
Help
￼￼￼￼￼￼￼￼Run￼￼￼￼
Code
￼￼
Snippets
In [1]:
￼
import pandas as pd
import matplotlib.pyplot as plt
import json
plt.rcParams.update({'font.size': 10})
​
In [6]:
￼
fig, ax = plt.subplots(6, 3, figsize=(18,30))
axdict = {'ax1':ax[0,0],'ax2':ax[0,1],'ax3':ax[0,2],
          'ax4':ax[1,0],'ax5':ax[1,1],'ax6':ax[1,2],
          'ax7':ax[2,0],'ax8':ax[2,1],'ax9':ax[2,2],
          'ax10':ax[3,0],'ax11':ax[3,1],'ax12':ax[3,2],
          'ax13':ax[4,0],'ax14':ax[4,1],'ax15':ax[4,2],
          'ax16':ax[5,0],'ax17':ax[5,1],'ax18':ax[5,2]}
marker ={'thirdmethod':'o','fourthmethod':'^','fifthmethod':'*','randomforest':'s','xgboost':'x'}
linestyle = {'thirdmethod': (0, (1, 10)),'fourthmethod':'dotted','fifthmethod':'dashed'}
​
​
# BPIC2015_1 label 0
​
label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+1)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
# BPIC2015_1 label 1
​
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+4)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
# BPIC2015_2 label 0
​
label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+7)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
# BPIC2015_2 label 1
​
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+10)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
​
# BPIC2015_3 label 0
​
label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+13)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
legenddict={}
   
# BPIC2015_3 label 1
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+16)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        legenddict[plabel] = scoregraph
​
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        legenddict[plabel] = scoregraph
​
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
​
​
fig.legend(legenddict.values(),     # The line objects
           labels=legenddict.keys(),   # The labels for each line
           loc="center right",   # Position of legend
               # Small spacing around legend box
           fontsize=20
           )
# plt.tight_layout()
plt.text(-16.5,5.85,'Precision',fontsize=20)
plt.text(-5.5,5.85,'Recall',fontsize=20)
plt.text(5,5.85,'F1-score',fontsize=20)
​
plt.text(-28.5,5.375,'BPIC 2015_1 Label 0',fontsize=20)
plt.text(-28.5,4.425,'BPIC 2015_1 Label 1',fontsize=20)
plt.text(-28.5,3.47,'BPIC 2015_2 Label 0',fontsize=20)
plt.text(-28.5,2.5,'BPIC 2015_2 Label 1',fontsize=20)
plt.text(-28.5,1.5,'BPIC 2015_3 Label 0',fontsize=20)
plt.text(-28.5,0.55,'BPIC 2015_3 Label 1',fontsize=20)
​
plt.subplots_adjust(left=0.2,right=0.87)
plt.subplots_adjust(right=0.85)
plt.savefig('./arm_ml1.pdf',bbox_inches='tight')
/home/iel03/.local/lib/python3.6/site-packages/ipykernel_launcher.py:270: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
￼
In [7]:
￼
fig, ax = plt.subplots(4, 3, figsize=(18,20))
axdict = {'ax1':ax[0,0],'ax2':ax[0,1],'ax3':ax[0,2],
          'ax4':ax[1,0],'ax5':ax[1,1],'ax6':ax[1,2],
          'ax7':ax[2,0],'ax8':ax[2,1],'ax9':ax[2,2],
          'ax10':ax[3,0],'ax11':ax[3,1],'ax12':ax[3,2]}
          
# BPIC2011 label 0
marker ={'thirdmethod':'o','fourthmethod':'^','fifthmethod':'*','randomforest':'s','xgboost':'x'}
linestyle = {'thirdmethod': (0, (1, 10)),'fourthmethod':'dotted','fifthmethod':'dashed'}
​
label = 'Label 0'
​
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+1)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
# BPIC2011 label 1
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+4)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
Python 3  Trusted 
File
Edit
View
Insert
Cell
Kernel
Help
￼￼￼￼￼￼￼￼Run￼￼￼￼
Code
￼￼
Snippets
In [1]:
￼
import pandas as pd
import matplotlib.pyplot as plt
import json
plt.rcParams.update({'font.size': 10})
​
In [6]:
￼
fig, ax = plt.subplots(6, 3, figsize=(18,30))
axdict = {'ax1':ax[0,0],'ax2':ax[0,1],'ax3':ax[0,2],
          'ax4':ax[1,0],'ax5':ax[1,1],'ax6':ax[1,2],
          'ax7':ax[2,0],'ax8':ax[2,1],'ax9':ax[2,2],
          'ax10':ax[3,0],'ax11':ax[3,1],'ax12':ax[3,2],
          'ax13':ax[4,0],'ax14':ax[4,1],'ax15':ax[4,2],
          'ax16':ax[5,0],'ax17':ax[5,1],'ax18':ax[5,2]}
marker ={'thirdmethod':'o','fourthmethod':'^','fifthmethod':'*','randomforest':'s','xgboost':'x'}
linestyle = {'thirdmethod': (0, (1, 10)),'fourthmethod':'dotted','fifthmethod':'dashed'}
​
​
# BPIC2015_1 label 0
​
label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+1)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
# BPIC2015_1 label 1
​
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+4)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
# BPIC2015_2 label 0
​
label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+7)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
# BPIC2015_2 label 1
​
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+10)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
​
# BPIC2015_3 label 0
​
label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+13)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
legenddict={}
   
# BPIC2015_3 label 1
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+16)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        legenddict[plabel] = scoregraph
​
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        legenddict[plabel] = scoregraph
​
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
​
​
fig.legend(legenddict.values(),     # The line objects
           labels=legenddict.keys(),   # The labels for each line
           loc="center right",   # Position of legend
               # Small spacing around legend box
           fontsize=20
           )
# plt.tight_layout()
plt.text(-16.5,5.85,'Precision',fontsize=20)
plt.text(-5.5,5.85,'Recall',fontsize=20)
plt.text(5,5.85,'F1-score',fontsize=20)
​
plt.text(-28.5,5.375,'BPIC 2015_1 Label 0',fontsize=20)
plt.text(-28.5,4.425,'BPIC 2015_1 Label 1',fontsize=20)
plt.text(-28.5,3.47,'BPIC 2015_2 Label 0',fontsize=20)
plt.text(-28.5,2.5,'BPIC 2015_2 Label 1',fontsize=20)
plt.text(-28.5,1.5,'BPIC 2015_3 Label 0',fontsize=20)
plt.text(-28.5,0.55,'BPIC 2015_3 Label 1',fontsize=20)
​
plt.subplots_adjust(left=0.2,right=0.87)
plt.subplots_adjust(right=0.85)
plt.savefig('./arm_ml1.pdf',bbox_inches='tight')
/home/iel03/.local/lib/python3.6/site-packages/ipykernel_launcher.py:270: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
￼
In [7]:
￼
fig, ax = plt.subplots(4, 3, figsize=(18,20))
axdict = {'ax1':ax[0,0],'ax2':ax[0,1],'ax3':ax[0,2],
          'ax4':ax[1,0],'ax5':ax[1,1],'ax6':ax[1,2],
          'ax7':ax[2,0],'ax8':ax[2,1],'ax9':ax[2,2],
          'ax10':ax[3,0],'ax11':ax[3,1],'ax12':ax[3,2]}
          
# BPIC2011 label 0
marker ={'thirdmethod':'o','fourthmethod':'^','fifthmethod':'*','randomforest':'s','xgboost':'x'}
linestyle = {'thirdmethod': (0, (1, 10)),'fourthmethod':'dotted','fifthmethod':'dashed'}
​
label = 'Label 0'
​
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+1)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
# BPIC2011 label 1
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+4)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
Python 3  Trusted 
File
Edit
View
Insert
Cell
Kernel
Help
￼￼￼￼￼￼￼￼Run￼￼￼￼
Code
￼￼
Snippets
In [1]:
￼
import pandas as pd
import matplotlib.pyplot as plt
import json
plt.rcParams.update({'font.size': 10})
​
In [6]:
￼
fig, ax = plt.subplots(6, 3, figsize=(18,30))
axdict = {'ax1':ax[0,0],'ax2':ax[0,1],'ax3':ax[0,2],
          'ax4':ax[1,0],'ax5':ax[1,1],'ax6':ax[1,2],
          'ax7':ax[2,0],'ax8':ax[2,1],'ax9':ax[2,2],
          'ax10':ax[3,0],'ax11':ax[3,1],'ax12':ax[3,2],
          'ax13':ax[4,0],'ax14':ax[4,1],'ax15':ax[4,2],
          'ax16':ax[5,0],'ax17':ax[5,1],'ax18':ax[5,2]}
marker ={'thirdmethod':'o','fourthmethod':'^','fifthmethod':'*','randomforest':'s','xgboost':'x'}
linestyle = {'thirdmethod': (0, (1, 10)),'fourthmethod':'dotted','fifthmethod':'dashed'}
​
​
# BPIC2015_1 label 0
​
label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+1)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
# BPIC2015_1 label 1
​
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+4)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
# BPIC2015_2 label 0
​
label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+7)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
# BPIC2015_2 label 1
​
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+10)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
​
# BPIC2015_3 label 0
​
label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+13)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
legenddict={}
   
# BPIC2015_3 label 1
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+16)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        legenddict[plabel] = scoregraph
​
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        legenddict[plabel] = scoregraph
​
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
​
​
fig.legend(legenddict.values(),     # The line objects
           labels=legenddict.keys(),   # The labels for each line
           loc="center right",   # Position of legend
               # Small spacing around legend box
           fontsize=20
           )
# plt.tight_layout()
plt.text(-16.5,5.85,'Precision',fontsize=20)
plt.text(-5.5,5.85,'Recall',fontsize=20)
plt.text(5,5.85,'F1-score',fontsize=20)
​
plt.text(-28.5,5.375,'BPIC 2015_1 Label 0',fontsize=20)
plt.text(-28.5,4.425,'BPIC 2015_1 Label 1',fontsize=20)
plt.text(-28.5,3.47,'BPIC 2015_2 Label 0',fontsize=20)
plt.text(-28.5,2.5,'BPIC 2015_2 Label 1',fontsize=20)
plt.text(-28.5,1.5,'BPIC 2015_3 Label 0',fontsize=20)
plt.text(-28.5,0.55,'BPIC 2015_3 Label 1',fontsize=20)
​
plt.subplots_adjust(left=0.2,right=0.87)
plt.subplots_adjust(right=0.85)
plt.savefig('./arm_ml1.pdf',bbox_inches='tight')
/home/iel03/.local/lib/python3.6/site-packages/ipykernel_launcher.py:270: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
￼
In [7]:
￼
fig, ax = plt.subplots(4, 3, figsize=(18,20))
axdict = {'ax1':ax[0,0],'ax2':ax[0,1],'ax3':ax[0,2],
          'ax4':ax[1,0],'ax5':ax[1,1],'ax6':ax[1,2],
          'ax7':ax[2,0],'ax8':ax[2,1],'ax9':ax[2,2],
          'ax10':ax[3,0],'ax11':ax[3,1],'ax12':ax[3,2]}
          
# BPIC2011 label 0
marker ={'thirdmethod':'o','fourthmethod':'^','fifthmethod':'*','randomforest':'s','xgboost':'x'}
linestyle = {'thirdmethod': (0, (1, 10)),'fourthmethod':'dotted','fifthmethod':'dashed'}
​
label = 'Label 0'
​
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+1)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​
    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
​
# BPIC2011 label 1
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+4)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)
​
    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)
​
            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)
​.pdf',bbox_inches='tight')
# Out:
# /home/iel03/.local/lib/python3.6/site-packages/ipykernel_launcher.py:183: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.

# %%
fig, ax = plt.subplots(6, 3, figsize=(22,30))
axdict = {'ax1':ax[0,0],'ax2':ax[0,1],'ax3':ax[0,2],
          'ax4':ax[1,0],'ax5':ax[1,1],'ax6':ax[1,2],
          'ax7':ax[2,0],'ax8':ax[2,1],'ax9':ax[2,2],
          'ax10':ax[3,0],'ax11':ax[3,1],'ax12':ax[3,2],
          'ax13':ax[4,0],'ax14':ax[4,1],'ax15':ax[4,2],
          'ax16':ax[5,0],'ax17':ax[5,1],'ax18':ax[5,2]}


# BPIC2015_1 label 0

label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+1)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Summarized_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Summarized_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Summarized_SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel,mfc='none')


    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')

# BPIC2015_1 label 1

label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+4)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_1/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Summarized_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Summarized_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Summarized_SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')

# BPIC2015_2 label 0

label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+7)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Summarized_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Summarized_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Summarized_SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel,mfc='none')


    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')

# BPIC2015_2 label 1

label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+10)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_2/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Summarized_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Summarized_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Summarized_SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel,mfc='none')


    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')


# BPIC2015_3 label 0

label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+13)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Summarized_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Summarized_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Summarized_SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel,mfc='none')

    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')

legenddict={}
   
# BPIC2015_3 label 1
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+16)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        legenddict[plabel] = scoregraph

        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2015/ltl1/bpic2015_3/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Summarized_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Summarized_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Summarized_SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel,mfc='none')
        legenddict[plabel] = scoregraph


    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')



fig.legend(legenddict.values(),     # The line objects
           labels=legenddict.keys(),   # The labels for each line
           loc="center right",   # Position of legend
               # Small spacing around legend box
           fontsize=16
           )
# plt.tight_layout()
plt.text(-16.5,5.85,'Precision',fontsize=20)
plt.text(-5.5,5.85,'Recall',fontsize=20)
plt.text(5,5.85,'F1-score',fontsize=20)

plt.text(-28.5,5.375,'BPIC 2015_1 Label 0',fontsize=20)
plt.text(-28.5,4.425,'BPIC 2015_1 Label 1',fontsize=20)
plt.text(-28.5,3.47,'BPIC 2015_2 Label 0',fontsize=20)
plt.text(-28.5,2.5,'BPIC 2015_2 Label 1',fontsize=20)
plt.text(-28.5,1.5,'BPIC 2015_3 Label 0',fontsize=20)
plt.text(-28.5,0.55,'BPIC 2015_3 Label 1',fontsize=20)

plt.subplots_adjust(left=0.2,right=0.85)
plt.subplots_adjust(right=0.85)
plt.savefig('./rulescreening1.pdf',bbox_inches='tight')
# Out:
# /home/iel03/.local/lib/python3.6/site-packages/ipykernel_launcher.py:283: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.

# %%
fig, ax = plt.subplots(4, 3, figsize=(22,20))
axdict = {'ax1':ax[0,0],'ax2':ax[0,1],'ax3':ax[0,2],
          'ax4':ax[1,0],'ax5':ax[1,1],'ax6':ax[1,2],
          'ax7':ax[2,0],'ax8':ax[2,1],'ax9':ax[2,2],
          'ax10':ax[3,0],'ax11':ax[3,1],'ax12':ax[3,2]}
          
# BPIC2011 label 0
marker ={'thirdmethod':'o','fourthmethod':'^','fifthmethod':'*','randomforest':'s','xgboost':'x'}
linestyle = {'thirdmethod': (0, (1, 10)),'fourthmethod':'dotted','fifthmethod':'dashed'}

label = 'Label 0'

for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+1)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Summarized_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Summarized_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Summarized_SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel,mfc='none')

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')

# BPIC2011 label 1
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+4)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../bpic2011/ltl1/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Summarized_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Summarized_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Summarized_SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel,mfc='none')

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')

# Sepsis cases label 0

label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+7)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../sepsis/rule1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../sepsis/rule1/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Summarized_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Summarized_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Summarized_SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel,mfc='none')

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')

# Sepsis cases label 1
legenddict={}
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+10)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../sepsis/rule1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        
        legenddict[plabel] = scoregraph
        
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../sepsis/rule1/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Summarized_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Summarized_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Summarized_SBOP'
        x = range(2,11)
        
        legenddict[plabel] = scoregraph
        
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel,mfc='none')

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length')
    
fig.legend(legenddict.values(),     # The line objects
           labels=legenddict.keys(),   # The labels for each line
           loc="center right",   # Position of legend
               # Small spacing around legend box
           fontsize=16
           )
# plt.tight_layout()
plt.text(-16.5,4.65,'Precision',fontsize=20)
plt.text(-5.5,4.65,'Recall',fontsize=20)
plt.text(5,4.65,'F1-score',fontsize=20)

plt.text(-27.9,4.05,'BPIC 2011 Label 0',fontsize=20)
plt.text(-27.9,2.85,'BPIC 2011 Label 1',fontsize=20)
plt.text(-27.9,1.65,'Sepsis cases Label 0',fontsize=20)
plt.text(-27.9,0.45,'Sepsis cases Label 1',fontsize=20)

plt.subplots_adjust(left=0.2,right=0.85)
# plt.tight_layout()
plt.savefig('./rulescreening2.pdf',bbox_inches='tight')
# Out:
# /home/iel03/.local/lib/python3.6/site-packages/ipykernel_launcher.py:191: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
