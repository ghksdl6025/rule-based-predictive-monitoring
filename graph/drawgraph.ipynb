# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
plt.rcParams.update({'font.size': 10})

# %%
fig, ax = plt.subplots(6, 3, figsize=(18,40))
axdict = {'ax1':ax[0,0],'ax2':ax[0,1],'ax3':ax[0,2],
          'ax4':ax[1,0],'ax5':ax[1,1],'ax6':ax[1,2],
          'ax7':ax[2,0],'ax8':ax[2,1],'ax9':ax[2,2],
          'ax10':ax[3,0],'ax11':ax[3,1],'ax12':ax[3,2],
          'ax13':ax[4,0],'ax14':ax[4,1],'ax15':ax[4,2],
          'ax16':ax[5,0],'ax17':ax[5,1],'ax18':ax[5,2]}

marker ={'thirdmethod':'o','fourthmethod':'^','fifthmethod':'*','randomforest':'s','xgboost':'x'}
linestyle = {'thirdmethod': (0, (1, 10)),'fourthmethod':'dotted','fifthmethod':'dashed'}
# BPIC2015_1 label 0

label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+1)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)


# BPIC2015_1 label 1

label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+4)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)


# BPIC2015_2 label 0

label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+7)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_2/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_2/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)


# BPIC2015_2 label 1

label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+10)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_2/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_2/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)



# BPIC2015_3 label 0

label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+13)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_3/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_3/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)


legenddict={}
   
# BPIC2015_3 label 1
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+16)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_3/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        legenddict[plabel] = scoregraph

        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_3/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        legenddict[plabel] = scoregraph

        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)

plt.subplots_adjust(bottom=0.05,hspace=0.4)
fig.legend(legenddict.values(),     # The line objects
           labels=legenddict.keys(),   # The labels for each line
           loc="lower center",   # Position of legend
               # Small spacing around legend box
           fontsize=20,
           ncol=5
           )

plt.text(-16.5,6.65,'Precision',fontsize=20)
plt.text(-5.5,6.65,'Recall',fontsize=20)
plt.text(5,6.65,'F1-score',fontsize=20)

plt.text(-7.8,6.75,'BPIC 2015_1 Label 0',fontsize=22)
plt.text(-7.8,5.5,'BPIC 2015_1 Label 1',fontsize=22)
plt.text(-7.8,4.4,'BPIC 2015_2 Label 0',fontsize=22)
plt.text(-7.8,3.25,'BPIC 2015_2 Label 1',fontsize=22)
plt.text(-7.8,2.15,'BPIC 2015_3 Label 0',fontsize=22)
plt.text(-7.8,1.05,'BPIC 2015_3 Label 1',fontsize=22)



plt.savefig('./arm_ml1.pdf',bbox_inches='tight')
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:274: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.

# %%
fig, ax = plt.subplots(4, 3, figsize=(18,25))
axdict = {'ax1':ax[0,0],'ax2':ax[0,1],'ax3':ax[0,2],
          'ax4':ax[1,0],'ax5':ax[1,1],'ax6':ax[1,2],
          'ax7':ax[2,0],'ax8':ax[2,1],'ax9':ax[2,2],
          'ax10':ax[3,0],'ax11':ax[3,1],'ax12':ax[3,2]}
          
# BPIC2011 label 0
marker ={'thirdmethod':'o','fourthmethod':'^','fifthmethod':'*','randomforest':'s','xgboost':'x'}
linestyle = {'thirdmethod': (0, (1, 10)),'fourthmethod':'dotted','fifthmethod':'dashed'}

label = 'Label 0'

for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+1)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2011/ltl1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2011/ltl1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)


# BPIC2011 label 1
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+4)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2011/ltl1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2011/ltl1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)

# Sepsis cases label 0

label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+7)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/sepsis/rule1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/sepsis/rule1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)

# Sepsis cases label 1
legenddict={}
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+10)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/sepsis/rule1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        
        legenddict[plabel] = scoregraph
        
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],markersize=12,label=plabel)

    for method in ['randomforest','xgboost']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/sepsis/rule1/ruleresult/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='randomforest':
            plabel = 'RF'
        elif method =='xgboost':
            plabel = 'XGB'
        x = range(2,11)
        
        legenddict[plabel] = scoregraph
        
        ax.plot(x,scoregraph,marker=marker[method],markersize=8,label=plabel)

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)
    
plt.subplots_adjust(bottom=0.08,hspace=0.4)
fig.legend(legenddict.values(),     # The line objects
           labels=legenddict.keys(),   # The labels for each line
           loc="lower center",   # Position of legend
               # Small spacing around legend box
           fontsize=20,
           ncol=5
           )

plt.text(-16.5,5.25,'Precision',fontsize=20)
plt.text(-5.5,5.25,'Recall',fontsize=20)
plt.text(5,5.25,'F1-score',fontsize=20)

plt.text(-7.8,5.4,'BPIC 2011 Label 0',fontsize=22)
plt.text(-7.8,3.85,'BPIC 2011 Label 1',fontsize=22)
plt.text(-7.8,2.45,'Sepsis cases Label 0',fontsize=22)
plt.text(-7.8,1.05,'Sepsis cases Label 1',fontsize=22)


plt.savefig('./arm_ml2.pdf',bbox_inches='tight')
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:186: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.

# %%
fig, ax = plt.subplots(6, 3, figsize=(18,40))
axdict = {'ax1':ax[0,0],'ax2':ax[0,1],'ax3':ax[0,2],
          'ax4':ax[1,0],'ax5':ax[1,1],'ax6':ax[1,2],
          'ax7':ax[2,0],'ax8':ax[2,1],'ax9':ax[2,2],
          'ax10':ax[3,0],'ax11':ax[3,1],'ax12':ax[3,2],
          'ax13':ax[4,0],'ax14':ax[4,1],'ax15':ax[4,2],
          'ax16':ax[5,0],'ax17':ax[5,1],'ax18':ax[5,2]}
marker ={'thirdmethod':'o','fourthmethod':'^','fifthmethod':'*','randomforest':'s','xgboost':'x'}
linestyle = {'thirdmethod': (0, (1, 10)),'fourthmethod':'dotted','fifthmethod':'dashed'}
colormaps = {'RSOP0':'#1f77b4','RSOP1':'#ff7f0e','SBOP':'#2ca02c','Pruned_RSOP0':'#1f77b4','Pruned_RSOP1':'#ff7f0e','Pruned_SBOP':'#2ca02c'}
# BPIC2015_1 label 0

label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+1)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],color=colormaps[plabel],markersize=12,label=plabel)

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_1/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Pruned_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Pruned_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Pruned_SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],color=colormaps[plabel],markersize=12,label=plabel,mfc='none')


    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)

# BPIC2015_1 label 1

label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+4)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],color=colormaps[plabel],markersize=12,label=plabel)

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_1/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Pruned_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Pruned_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Pruned_SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],color=colormaps[plabel],markersize=12,label=plabel,mfc='none')

    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)

# BPIC2015_2 label 0

label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+7)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_2/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],color=colormaps[plabel],markersize=12,label=plabel)

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_2/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Pruned_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Pruned_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Pruned_SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],color=colormaps[plabel],markersize=12,label=plabel,mfc='none')


    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)

# BPIC2015_2 label 1

label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+10)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_2/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],color=colormaps[plabel],markersize=12,label=plabel)

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_2/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Pruned_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Pruned_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Pruned_SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],color=colormaps[plabel],markersize=12,label=plabel,mfc='none')


    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)


# BPIC2015_3 label 0

label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+13)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_3/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],color=colormaps[plabel],markersize=12,label=plabel)

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_3/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Pruned_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Pruned_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Pruned_SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],color=colormaps[plabel],markersize=12,label=plabel,mfc='none')

    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)

legenddict={}
   
# BPIC2015_3 label 1
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+16)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_3/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        legenddict[plabel] = scoregraph

        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],color=colormaps[plabel],markersize=12,label=plabel)

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2015/ltl1/bpic2015_3/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Pruned_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Pruned_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Pruned_SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[method],marker=marker[method],color=colormaps[plabel],markersize=12,label=plabel,mfc='none')
        legenddict[plabel] = scoregraph

    ax.set_ylim(0.2,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)

plt.subplots_adjust(bottom=0.05,hspace=0.4)
labels = ['RSOP0', 'Pruned_RSOP0', 'RSOP1', 'Pruned_RSOP1', 'SBOP', 'Pruned_SBOP']
marker ={'RSOP0':'o','RSOP1':'^','SBOP':'*','Pruned_RSOP0':'o','Pruned_RSOP1':'^','Pruned_SBOP':'*'}
colormaps = {'RSOP0':'#1f77b4','RSOP1':'#ff7f0e','SBOP':'#2ca02c','Pruned_RSOP0':'#1f77b4','Pruned_RSOP1':'#ff7f0e','Pruned_SBOP':'#2ca02c'}
linestyle = {'RSOP0': (0, (1, 10)),'RSOP1':'dotted','SBOP':'dashed','Pruned_RSOP0': (0, (1, 10)),'Pruned_RSOP1':'dotted','Pruned_SBOP':'dashed'}
patches = []
for i in labels:
    if 'Pruned' in i:
        patches.append(plt.plot([],[], linestyle=linestyle[i],marker=marker[i], ms=12, color = colormaps[i],mfc='none',label="{:s}".format(i) )[0])
    else:
        patches.append(plt.plot([],[], linestyle=linestyle[i],marker=marker[i], ms=12, color = colormaps[i],label="{:s}".format(i) )[0])


fig.legend(handles=patches,
           loc="lower center",   # Position of legend
               # Small spacing around legend box
           fontsize=20,
           ncol=6
           )

plt.text(-16.5,6.65,'Precision',fontsize=20)
plt.text(-5.5,6.65,'Recall',fontsize=20)
plt.text(5,6.65,'F1-score',fontsize=20)

plt.text(-7.5,6.75,'BPIC 2015_1 Label 0',fontsize=22)
plt.text(-7.5,5.5,'BPIC 2015_1 Label 1',fontsize=22)
plt.text(-7.5,4.4,'BPIC 2015_2 Label 0',fontsize=22)
plt.text(-7.5,3.3,'BPIC 2015_2 Label 1',fontsize=22)
plt.text(-7.5,2.15,'BPIC 2015_3 Label 0',fontsize=22)
plt.text(-7.5,1.05,'BPIC 2015_3 Label 1',fontsize=22)
plt.savefig('./rulescreening1.pdf',bbox_inches='tight')

# %%
fig, ax = plt.subplots(4, 3, figsize=(18,25))
axdict = {'ax1':ax[0,0],'ax2':ax[0,1],'ax3':ax[0,2],
          'ax4':ax[1,0],'ax5':ax[1,1],'ax6':ax[1,2],
          'ax7':ax[2,0],'ax8':ax[2,1],'ax9':ax[2,2],
          'ax10':ax[3,0],'ax11':ax[3,1],'ax12':ax[3,2]}
          
# BPIC2011 label 0
labels = ['RSOP0', 'Pruned_RSOP0', 'RSOP1', 'Pruned_RSOP1', 'SBOP', 'Pruned_SBOP']
marker ={'RSOP0':'o','RSOP1':'^','SBOP':'*','Pruned_RSOP0':'o','Pruned_RSOP1':'^','Pruned_SBOP':'*'}
colormaps = {'RSOP0':'#1f77b4','RSOP1':'#ff7f0e','SBOP':'#2ca02c','Pruned_RSOP0':'#1f77b4','Pruned_RSOP1':'#ff7f0e','Pruned_SBOP':'#2ca02c'}

label = 'Label 0'

for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+1)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2011/ltl1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[plabel],marker=marker[plabel],markersize=12,label=plabel,color=colormaps[plabel])

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2011/ltl1/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Pruned_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Pruned_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Pruned_SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[plabel],marker=marker[plabel],markersize=12,label=plabel,mfc='none',color=colormaps[plabel])

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)

# BPIC2011 label 1
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+4)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2011/ltl1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[plabel],marker=marker[plabel],markersize=12,label=plabel,color=colormaps[plabel])

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/bpic2011/ltl1/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Pruned_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Pruned_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Pruned_SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[plabel],marker=marker[plabel],markersize=12,label=plabel,mfc='none',color=colormaps[plabel])

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)

# Sepsis cases label 0

label = 'Label 0'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+7)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/sepsis/rule1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[plabel],marker=marker[plabel],markersize=12,label=plabel,color=colormaps[plabel])

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/sepsis/rule1/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Pruned_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Pruned_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Pruned_SBOP'
        x = range(2,11)
        ax.plot(x,scoregraph,linestyle=linestyle[plabel],marker=marker[plabel],markersize=12,label=plabel,mfc='none',color=colormaps[plabel])

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)

# Sepsis cases label 1
legenddict={}
label = 'Label 1'
for pos,score in enumerate(['precision','recall','f1-score']):
    ax = axdict['ax'+str(pos+10)]
    
    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/sepsis/rule1/ruleresult/way3/'+method+'/prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'RSOP0'
        elif method =='fourthmethod':
            plabel = 'RSOP1'
        elif method == 'fifthmethod':
            plabel = 'SBOP'
        x = range(2,11)
        
        legenddict[plabel] = scoregraph
        
        ax.plot(x,scoregraph,linestyle=linestyle[plabel],marker=marker[plabel],markersize=12,label=plabel,color=colormaps[plabel])

    for method in ['thirdmethod','fourthmethod','fifthmethod']:
        scoregraph = []
        for prefix in range(2,11):
            with open('../data/sepsis/rule1/ruleresult/way3/'+method+'/Summarized_prefix'+str(prefix)+'result.json','r') as f:
                resultdict = json.load(f)

            scoregraph.append(resultdict[label][score][0])
        if method =='thirdmethod':
            plabel = 'Pruned_RSOP0'
        elif method =='fourthmethod':
            plabel = 'Pruned_RSOP1'
        elif method == 'fifthmethod':
            plabel = 'Pruned_SBOP'
        x = range(2,11)
        
        legenddict[plabel] = scoregraph
        
        ax.plot(x,scoregraph,linestyle=linestyle[plabel],marker=marker[plabel],markersize=12,label=plabel,mfc='none',color=colormaps[plabel])

    ax.set_ylim(0,1)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Prefix length',fontsize=18)

    
plt.subplots_adjust(bottom=0.08,hspace=0.4)
labels = ['RSOP0', 'Pruned_RSOP0', 'RSOP1', 'Pruned_RSOP1', 'SBOP', 'Pruned_SBOP']
marker ={'RSOP0':'o','RSOP1':'^','SBOP':'*','Pruned_RSOP0':'o','Pruned_RSOP1':'^','Pruned_SBOP':'*'}
colormaps = {'RSOP0':'#1f77b4','RSOP1':'#ff7f0e','SBOP':'#2ca02c','Pruned_RSOP0':'#1f77b4','Pruned_RSOP1':'#ff7f0e','Pruned_SBOP':'#2ca02c'}
linestyle = {'RSOP0': (0, (1, 10)),'RSOP1':'dotted','SBOP':'dashed','Pruned_RSOP0': (0, (1, 10)),'Pruned_RSOP1':'dotted','Pruned_SBOP':'dashed'}
patches = []
for i in labels:
    if 'Pruned' in i:
        patches.append(plt.plot([],[], linestyle=linestyle[i],marker=marker[i], ms=12, color = colormaps[i],mfc='none',label="{:s}".format(i) )[0])
    else:
        patches.append(plt.plot([],[], linestyle=linestyle[i],marker=marker[i], ms=12, color = colormaps[i],label="{:s}".format(i) )[0])


fig.legend(handles=patches,
           loc="lower center",   # Position of legend
               # Small spacing around legend box
           fontsize=20,
           ncol=6
           )

plt.text(-16.5,5.25,'Precision',fontsize=20)
plt.text(-5.5,5.25,'Recall',fontsize=20)
plt.text(5,5.25,'F1-score',fontsize=20)

plt.text(-7.3,5.4,'BPIC 2011 Label 0',fontsize=22)
plt.text(-7.3,3.85,'BPIC 2011 Label 1',fontsize=22)
plt.text(-7.3,2.45,'Sepsis cases Label 0',fontsize=22)
plt.text(-7.3,1.05,'Sepsis cases Label 1',fontsize=22)


plt.savefig('./rulescreening2.pdf',bbox_inches='tight')
